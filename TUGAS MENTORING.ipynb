# %%
odd=[x for x in range(1,100+1) if x %2!=0]
squares=[x**2 for x in odd]
total=sum(squares)
ratarata=total/len(squares)
print(total)
print(ratarata)
# Out:
# 166650
# 3333.0

# %%
a = int(input("masukan a= "))
if a<100: #conditional form
    print('small value')
else:
    print('big value')
# Out:
# masukan a= 80
# small value

# %%
while True:
  a = int(input("masukan a= "))
  if a<100:
    print('small value')
  else:
    print('big value')
    break
# Out:
# masukan a= 70
# small value
# masukan a= 110
# big value

# %%
pas= input("password= ")
panjang=len(pas)>=5
c8="8" in pas
cx= "X" in pas
char="@" in pas
if panjang!=True:
    print("terlalu pendek")
elif c8!=True:
    print("harus mengandung 8")
elif cx!=True:
    print("harus mengandng X")
elif char!=True:
    print("harus mengandng @")
else:
    print("password valid")
# Out:
# password= reyhan@
# harus mengandung 8

# %%
while True:
    pas= input("password= ")
    panjang=len(pas)>=5
    c8="8" in pas
    cx= "X" in pas
    char="@" in pas
    if panjang!=True:
        print("terlalu pendek")
    elif c8!=True:
        print("harus mengandung 8")
    elif cx!=True:
        print("harus mengandng X")
    elif char!=True:
        print("harus mengandng @")
    else:
        print("password valid")
        break
# Out:
# password= reyhan@
# harus mengandung 8
# password= reyhan@#$
# harus mengandung 8
# password= Reyhan21#$@
# harus mengandung 8
# password= Reyhanx8@
# harus mengandng X
# password= Reyhan8X@
# password valid

# %%
count=0
contoh_list=['acc', 'xyz', 'aba', '1234']
for i in range(len(contoh_list)):
    if(contoh_list[i][0] == contoh_list[i][-1]):
        count += 1
print('jumlah string yg sama=',count)
print(contoh_list)
# Out:
# jumlah string yg sama= 1
# ['acc', 'xyz', 'aba', '1234']

# %%
while True:
    kata=input("masukan kata= ")
    if kata == kata[::-1]:
        print("string merupakan palidrom")
        break
    else:
        print("string bukan palidrom")
# Out:
# masukan kata= reyhan
# string bukan palidrom
# masukan kata= kodok
# string merupakan palidrom

# %%
def hitung(s):
    d={'upper':0,'lower':0}
    for x in s:
        if x.isupper():
            d['upper']+=1
        elif x.islower():
            d['lower']+=1
    print('string kalimat:', s)
    print('jumlah huruf kapital:',d['upper'])
    print('jumlah huruf kecil',d['lower'])
hitung('aAsssssSsSWWWJHSJ')
# Out:
# string kalimat: aAsssssSsSWWWJHSJ
# jumlah huruf kapital: 10
# jumlah huruf kecil 7

# %%
#Kata ganjil
list1=["ada","sapa","warga","kanopi","layang","tamu","kampus"]
for i in list1:
    if len(i)%2==1:
        print(i,end=" ")
# Out:
# ada warga

# %%
#kata genap
list1=["dia","sapa","warga","kanopi","layang","tamu"]
for i in list1:
    if len(i)%2==0:
        print(i,end=" ")
# Out:
# sapa kanopi layang tamu

# %%
username = input("masukkan username: [4-10 characters] ")

if 4 <= len(username) <= 10:
    print(f"terimakasih . The username {username} benar")
else:
    print("username harus 4 sampai 10 characters ")
# Out:
# masukkan username: [4-10 characters] reyhan
# terimakasih . The username reyhan benar

# %%
usernames = []

print("masukkan username")

while len(usernames) < 3:
    username = input("masukkan sausername: [4-10 characters] ")
    if 4 <= len(username) <= 10:
        print(f"terimaksih {username} benar")
        usernames.append(username)
    else:
        print("username harys 4 sampai 10 characters ")

print(usernames)
# Out:
# masukkan username
# masukkan sausername: [4-10 characters] reyhan
# terimaksih reyhan benar
# masukkan sausername: [4-10 characters] andi
# terimaksih andi benar
# masukkan sausername: [4-10 characters] yang
# terimaksih yang benar
# ['reyhan', 'andi', 'yang']

# %%
nilai = 90

print('Nilai anda adalah:', nilai, '\n')

if nilai >= 70:
  print('Selamat, anda lulus!')
else:
  print('Maaf, anda tidak lulus.')
# Out:
# Nilai anda adalah: 90
#
# Selamat, anda lulus!

# %%
nilai = int(input('Masukkan nilai: '))

if nilai >= 90:
  print('Predikat A')
elif nilai >= 80:
  print('Predikat B')
elif nilai >= 60:
  print('Predikat C')
elif nilai >= 40:
  print('Predikat D')
else:
  print('Predikat E')
# Out:
# Masukkan nilai: 89
# Predikat B

# %%
buah_yang_tersedia = ['jeruk', 'mangga', 'melon']
buah_yang_dicari = input('Masukkan nama buah dalam huruf kecil: ')

if (buah_yang_dicari in buah_yang_tersedia):
  print('Buah yang anda cari tersedia!')
else:
  print('Buah yang anda cari tidak tersedia!')
# Out:
# Masukkan nama buah dalam huruf kecil: jeruk
# Buah yang anda cari tersedia!

# %%
nilai = int(input('Masukkan nilai: '))
usia = int(input('Masukkan usia: '))

if nilai >= 75:
  if (usia < 15):
    print('Selamat adek, kamu lulus!')
  else:
    print('Selamat kakak, kamu lulus!')
else:
  if (usia < 15):
    print('Mohon maaf dek, coba lagi ya!')
  else:
    print('Mohon maaf kak, coba lagi ya!')
# Out:
# Masukkan nilai: 87
# Masukkan usia: 22
# Selamat kakak, kamu lulus!
